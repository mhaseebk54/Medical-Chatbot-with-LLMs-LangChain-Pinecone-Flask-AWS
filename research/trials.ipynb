# %%
print("helo")
# Out:
# helo

# %%
# %pwd
# Out:
# 'e:\\Medical Rag Chatbot\\AI Medical Chatbot with RAG\\research'

# %%
import os
os.chdir("../")

# %%
# !pip install langchain==0.3.26 sentence-transformers==4.1.0 pypdf==5.6.1 python-dotenv==1.1.0 langchain-pinecone==0.2.8  langchain-ollama langchain-community==0.3.26

# %%
# %pwd
# Out:
# 'e:\\Medical Rag Chatbot\\AI Medical Chatbot with RAG'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from langchain.document_loaders import PyPDFLoader, DirectoryLoader
#       2 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain'
